# %%
import pandas as pd

# %%
data = pd.read_csv('/home/pswiat/studia/Agents/outputs/interesting_rows_20260508_115156.csv')

# %%
# add 3 empty columns to the right of the dataframe
data['groundedness_socre'] = ''
data['relevance_score'] = ''
data['clarity_score'] = ''
data['innovation_score'] = ''

# %%
data.to_csv('/home/pswiat/studia/Agents/outputs/interesting_rows_20260508_115156_annotated.csv', index=False)
